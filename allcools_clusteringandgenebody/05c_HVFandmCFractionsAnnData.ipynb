# %% [markdown]
# #from allcools page: https://lhqing.github.io/ALLCools/cell_level/step_by_step/100kb/03-HighlyVariableFeatureSelection.html
# Calculate Highly Variable Features And Get mC Fraction AnnData¶
#
# Purpose
# The purpose of this step is to select highly variable features (HVF) and generate cell-by-feature methylation fraction matrix for clustering. The highly variable features are selected by comparing feature’s normalized dispersion among cells.

# %%
Input¶
Filtered cell metadata;

MCDS files;

Feature list from basic feature filtering

Output
cell-by-HVF methylation fraction matrix stored in AnnData format, e.g., mCH adata and mCG adata.

# %%
cd /share/lasallelab/Ensi/project/allcools/oocytes/
# Out:
# /share/lasallelab/Ensi/project/allcools/oocytes

# %%
conda activate /share/lasallelab/Ensi/anaconda3/allcools/
# Out:
# usage: conda [-h] [--no-plugins] [-V] COMMAND ...
# conda: error: argument COMMAND: invalid choice: 'activate' (choose from 'clean', 'compare', 'config', 'create', 'info', 'init', 'install', 'list', 'notices', 'package', 'remove', 'uninstall', 'rename', 'run', 'search', 'update', 'upgrade', 'build', 'content-trust', 'convert', 'debug', 'develop', 'doctor', 'index', 'inspect', 'metapackage', 'render', 'repoquery', 'skeleton', 'verify', 'token', 'repo', 'env', 'server', 'pack')

# %%
import pathlib
import pandas as pd
import dask
from ALLCools.mcds import MCDS

# %%
# If True, will load all data into memory.
# Computation will be much faster, but also very memory intensive, only use this for small number of cells (<10,000)
load = True

# change this to the path to your filtered metadata
metadata_path = '../../CellMetadata_PassQC_alloocytes_withyear_mtreads_sub.csv'

# change this to the paths to your MCDS files
mcds_path = '../mcds'

# Feature list after basic filter
feature_path = 'FeatureList.BasicFilter.txt'

# Dimension name used to do clustering
obs_dim = 'cell'  # observation
var_dim = 'chrom100k'  # feature

# HVF method:
# SVR: regression based
# Bins: normalize dispersion per bin
hvf_method = 'SVR'
mch_pattern = 'CHN'
mcg_pattern = 'CGN'
n_top_feature = 31645

# Downsample cells
downsample = 20000

# %%
metadata = pd.read_csv(metadata_path, index_col=0, sep="\t")
metadata = metadata[metadata["Type"] == "PO"]
total_cells = metadata.shape[0]
print(f'Metadata of {total_cells} cells')
metadata
# Out:
# Metadata of 46 cells
#                                  SampleI  AnimalID   Date Animdate  \
# SampleID
# 4146045001PO3NC4G4C   4146045001PO3NC4G4     41460  45001       f2
# 4129944963PO2NC4M1S   4129944963PO2NC4M1     41299  44963       d2
# 4520844650PO1NC5A7S   4520844650PO1NC5A7     45208  44650       n1
# 4146045001PO2NC3F4C   4146045001PO2NC3F4     41460  45001       f2
# 4520844650PO2NC3B7S   4520844650PO2NC3B7     45208  44650       n1
# 3905345005PO1NC2I1S   3905345005PO1NC2I1     39053  45005       b1
# 4129944963PO1NC3N1S   4129944963PO1NC3N1     41299  44963       d2
# 4211144957PO1NC3K4C   4211144957PO1NC3K4     42111  44957       g1
# 4660644938PO2NC3A10C  4660644938PO2NC3A1     46606  44938       r1
# 4139144923PO4NC4K3C   4139144923PO4NC4K3     41391  44923       e1
# 4598244908PO1NC3J8C   4598244908PO1NC3J8     45982  44908       p1
# 4598244908PO2NC4K8C   4598244908PO2NC4K8     45982  44908       p1
# 4566944964PO2NC4C7C   4566944964PO2NC4C7     45669  44964       o2
# 4129944963PO3NC3O1S   4129944963PO3NC3O1     41299  44963       d2
# 4129944963PO1NC3N1S            2  2023  Pooled Oocytes (3) #1     N1
# 4211144957PO1NC3K4C            1  2023  Pooled Oocytes (3) #1     K4
# 4660644938PO2NC3A10C           1  2023  Pooled Oocytes (3) #2    A10
# 4139144923PO4NC4K3C            1  2022  Pooled Oocytes (4) #4     K3
# 4598244908PO1NC3J8C            1  2022  Pooled Oocytes (3) #1     J8
# 4598244908PO2NC4K8C            1  2022  Pooled Oocytes (4) #2     K8
# 4566944964PO2NC4C7C            2  2023  Pooled Oocytes (4) #2     C7
# 4129944963PO3NC3O1S            1  2023  Pooled Oocytes (3) #3     O1
# 4139144923PO3NC5J3C            1  2022  Pooled Oocytes (5) #3     J3
# 4566944964PO3NC3D8C            2  2023  Pooled Oocytes (3) #3     D8
# 4265145042PO3NC4G5S            1  2023  Pooled Oocytes (4) #3     G5
# 4598245001PO2NC4F8C            2  2023  Pooled Oocytes (4) #2     F8
# 4499445005PO2NC3C5C            2  2023  Pooled Oocytes (3) #2     C5
# 4660644993PO2NC5D10C           2  2023  Pooled Oocytes (5) #2    D10
# 4566944964PO4NC3E8C            2  2023  Pooled Oocytes (3) #4     E8
# 4660644938PO3NC5B10C           1  2023  Pooled Oocytes (5) #3    B10
# 4636344664PO1NC5L9C            1  2022  Pooled Oocytes (5) #1     L9
# 4566944700PO1NC5O8C            1  2022  Pooled Oocytes (5) #1     O8
# 4636344914PO1NC4H9C            2  2022  Pooled Oocytes (4) #1     H9
# 4265145042PO2NC4N4S            1  2023  Pooled Oocytes (4) #2     N4
# 4660644993PO3NC5E10C           2  2023  Pooled Oocytes (5) #3    E10
# 4211144957PO2NC3L4C            1  2023  Pooled Oocytes (3) #2     L4
# 3889744700PO1NC5D1S            2  2022  Pooled Oocytes (5) #1     D1
# 4265145042PO1NC3E5S            1  2023  Pooled Oocytes (3) #1     E5
# 4660644993PO4NC5F10C           2  2023  Pooled Oocytes (5) #4    F10
# 4146044643PO3NC5A4C            1  2022  Pooled Oocytes (5) #3     A4
# 4146045001PO1NC5E4C            2  2023  Pooled Oocytes (5) #1     E4
# 4139144650PO1NC4F3C            2  2022  Pooled Oocytes (4) #1     F3
# 4139144650PO2NC4G3C            2  2022  Pooled Oocytes (4) #2     G3
# 4520844650PO3NC5C8S            1  2022  Pooled Oocytes (5) #3     C8
# 4566944700PO2NC5P8C            1  2022  Pooled Oocytes (5) #2     P8
# 4146044643PO1NC5O3C            1  2022  Pooled Oocytes (5) #1     O3
# 4456444991PO1NC3H6C            1  2023  Pooled Oocytes (3) #1     H6
# 4139144923PO2NC3I3C            1  2022  Pooled Oocytes (3) #2     I3
# 4146044643PO2NC5P3C            1  2022  Pooled Oocytes (5) #2     P3
# 4139144650PO3NC3E3C            2  2022  Pooled Oocytes (3) #3     E3
# 4566944700PO3NC4A9C            1  2022  Pooled Oocytes (4) #3     A9
# 4302844664PO2NC5K5C            1  2022  Pooled Oocytes (5) #2     K5
# 4139144923PO1NC3H3C            1  2022  Pooled Oocytes (3) #1     H3
# 4123744641PO1NC4N2S            1  2022  Pooled Oocytes (4) #1     N2
#
#                      WellBarcode Type  TotalRead  mCGFrac     Group  \
# SampleID
# 4146045001PO3NC4G4C     TCGTGCAT   PO    2200000    0.689   Control
# 4129944963PO2NC4M1S     CACGCAAT   PO    2300000    0.684  Stressed
# 4520844650PO1NC5A7S     ATCGTCTC   PO    2400000    0.676  Stressed
# 4146045001PO2NC3F4C     CTGAACGT   PO    2500000    0.686   Control
# 4520844650PO2NC3B7S     CTCTGGAT   PO    2600000    0.680  Stressed
# 3905345005PO1NC2I1S     TGATAGGC   PO    2700000    0.623  Stressed
# 4129944963PO1NC3N1S     ATTCCGCT   PO    2900000    0.626  Stressed
# 4211144957PO1NC3K4C     ACTGGTGT   PO    3200000    0.674   Control
# 4660644938PO2NC3A10C    GATCTTGC   PO    3600000    0.680   Control
# 4139144923PO4NC4K3C     GAACCTTC   PO    4100000    0.629   Control
# 4598244908PO1NC3J8C     GATAGCCA   PO    4200000    0.701   Control
# 4598244908PO2NC4K8C     AGCCAACT   PO    4300000    0.670   Control
# 4566944964PO2NC4C7C     CGGTAATC   PO    4400000    0.654   Control
# 4129944963PO3NC3O1S     AGAAGGAC   PO    4800000    0.641  Stressed
# 4139144923PO3NC5J3C     GTATCGAG   PO    5000000    0.622   Control
# 4566944964PO3NC3D8C     AACACGCT   PO    5000000    0.664   Control
# 4265145042PO3NC4G5S     CAAGTCGT   PO    5100000    0.686  Stressed
# 4598245001PO2NC4F8C     GTCTGCAA   PO    5600000    0.668   Control
# 4499445005PO2NC3C5C     ATCGTGGT   PO    6000000    0.714   Control
# 4660644993PO2NC5D10C    ACTCGATC   PO    6100000    0.702   Control
# 4566944964PO4NC3E8C     ACGTCCAA   PO    6300000    0.674   Control
# 4660644938PO3NC5B10C    CCAACGAA   PO    7200000    0.694   Control
# 4636344664PO1NC5L9C     AACACCAC   PO    8100000    0.700   Control
# 4566944700PO1NC5O8C     ACATGGAG   PO    8300000    0.713   Control
# 4636344914PO1NC4H9C     ACGAGAAC   PO    8300000    0.711   Control
# 4265145042PO2NC4N4S     CCTACCTA   PO    8700000    0.584  Stressed
# 4660644993PO3NC5E10C    GATCCACT   PO    8800000    0.684   Control
# 4211144957PO2NC3L4C     CAGGTTCA   PO    9100000    0.682   Control
# 3889744700PO1NC5D1S     CAGTCACA   PO   10700000    0.693  Stressed
# 4265145042PO1NC3E5S     CTTCGCAA   PO   11100000    0.684  Stressed
# 4660644993PO4NC5F10C    CCACATTG   PO   11400000    0.681   Control
# 4146044643PO3NC5A4C     TGTTCCGT   PO   11500000    0.690   Control
# 4146045001PO1NC5E4C     CCAACTTC   PO   12000000    0.704   Control
# 4139144650PO1NC4F3C     AGATTGCG   PO   12100000    0.668   Control
# 4139144650PO2NC4G3C     TACACACG   PO   13400000    0.693   Control
# 4520844650PO3NC5C8S     TAGCCATG   PO   14800000    0.667  Stressed
# 4566944700PO2NC5P8C     TGGATGGT   PO   14900000    0.690   Control
# 4146044643PO1NC5O3C     GCGTATCA   PO   15200000    0.697   Control
# 4456444991PO1NC3H6C     ACCGGTTA   PO   17500000    0.725   Control
# 4139144923PO2NC3I3C     CATCCAAG   PO   18400000    0.683   Control
# 4146044643PO2NC5P3C     GTTAAGCG   PO   18500000    0.699   Control
# 4139144650PO3NC3E3C     GACGAACT   PO   27100000    0.691   Control
# 4566944700PO3NC4A9C     TCGACAAG   PO   28200000    0.714   Control
# 4302844664PO2NC5K5C     AGCGAGAT   PO   33700000    0.715   Control
# 4139144923PO1NC3H3C     AGTCGAAG   PO   42800000    0.700   Control
# 4123744641PO1NC4N2S     AAGCGACT   PO   50200000    0.716  Stressed
#
#                                                              SampleName  \
# SampleID
# 4146045001PO3NC4G4C   4146045001PO3NC4G4C_1_val_1_bismark_bt2_pe.all...
# 4129944963PO2NC4M1S   4129944963PO2NC4M1S_1_val_1_bismark_bt2_pe.all...
# 4520844650PO1NC5A7S   4520844650PO1NC5A7S_1_val_1_bismark_bt2_pe.all...
# 4146045001PO2NC3F4C   4146045001PO2NC3F4C_1_val_1_bismark_bt2_pe.all...
# 4520844650PO2NC3B7S   4520844650PO2NC3B7S_1_val_1_bismark_bt2_pe.all...
# 3905345005PO1NC2I1S   3905345005PO1NC2I1S_1_val_1_bismark_bt2_pe.all...
# 4129944963PO1NC3N1S   4129944963PO1NC3N1S_1_val_1_bismark_bt2_pe.all...
# 4211144957PO1NC3K4C   4211144957PO1NC3K4C_1_val_1_bismark_bt2_pe.all...
# 4660644938PO2NC3A10C  4660644938PO2NC3A10C_1_val_1_bismark_bt2_pe.al...
# 4139144923PO4NC4K3C   4139144923PO4NC4K3C_1_val_1_bismark_bt2_pe.all...
# 4598244908PO1NC3J8C   4598244908PO1NC3J8C_1_val_1_bismark_bt2_pe.all...
# 4598244908PO2NC4K8C   4598244908PO2NC4K8C_1_val_1_bismark_bt2_pe.all...
# 4566944964PO2NC4C7C   4566944964PO2NC4C7C_1_val_1_bismark_bt2_pe.all...
# 4129944963PO3NC3O1S   4129944963PO3NC3O1S_1_val_1_bismark_bt2_pe.all...
# 4139144923PO3NC5J3C   4139144923PO3NC5J3C_1_val_1_bismark_bt2_pe.all...
# 4566944964PO3NC3D8C   4566944964PO3NC3D8C_1_val_1_bismark_bt2_pe.all...
# 4265145042PO3NC4G5S   4265145042PO3NC4G5S_1_val_1_bismark_bt2_pe.all...
# 4598245001PO2NC4F8C   4598245001PO2NC4F8C_1_val_1_bismark_bt2_pe.all...
# 4499445005PO2NC3C5C   4499445005PO2NC3C5C_1_val_1_bismark_bt2_pe.all...
# 4660644993PO2NC5D10C  4660644993PO2NC5D10C_1_val_1_bismark_bt2_pe.al...
# 4566944964PO4NC3E8C   4566944964PO4NC3E8C_1_val_1_bismark_bt2_pe.all...
# 4660644938PO3NC5B10C  4660644938PO3NC5B10C_1_val_1_bismark_bt2_pe.al...
# 4636344664PO1NC5L9C   4636344664PO1NC5L9C_1_val_1_bismark_bt2_pe.all...
# 4211144957PO1NC3K4C       3039304                77312          NaN
# 4660644938PO2NC3A10C      3742728                50728          NaN
# 4139144923PO4NC4K3C       4376010                29726          NaN
# 4598244908PO1NC3J8C       4695158                 7030          NaN
# 4598244908PO2NC4K8C       4176152               109518          NaN
# 4566944964PO2NC4C7C       4962360                19428          NaN
# 4129944963PO3NC3O1S       3568352               265864          NaN
# 4139144923PO3NC5J3C       5138862                53978          NaN
# 4566944964PO3NC3D8C       6058252                17386          NaN
# 4265145042PO3NC4G5S       5531502                51102          NaN
# 4598245001PO2NC4F8C       6318498                26454          NaN
# 4499445005PO2NC3C5C       7126154                 8516          NaN
# 4660644993PO2NC5D10C      6717552                60522          NaN
# 4566944964PO4NC3E8C       7451290                23862          NaN
# 4660644938PO3NC5B10C      8783292                17192          NaN
# 4636344664PO1NC5L9C       9092498                24108          NaN
# 4566944700PO1NC5O8C       9429066                 8488          NaN
# 4636344914PO1NC4H9C       9261718                44148          NaN
# 4265145042PO2NC4N4S       9483046                35410          NaN
# 4660644993PO3NC5E10C      9834078                52552          NaN
# 4211144957PO2NC3L4C       9947086               107540          NaN
# 3889744700PO1NC5D1S      11289778               132480          NaN
# 4265145042PO1NC3E5S      12435942                55356          NaN
# 4660644993PO4NC5F10C     12310004               118550          NaN
# 4146044643PO3NC5A4C      13059338                54468          NaN
# 4146045001PO1NC5E4C      13528962               116542          NaN
# 4139144650PO1NC4F3C      14262148                31868          NaN
# 4139144650PO2NC4G3C      15504190                22328          NaN
# 4520844650PO3NC5C8S      16555386                87572          NaN
# 4566944700PO2NC5P8C      16581752                33038          NaN
# 4146044643PO1NC5O3C      16775166               104620          NaN
# 4456444991PO1NC3H6C      19743522                43828          NaN
# 4139144923PO2NC3I3C      20816640                34768          NaN
# 4146044643PO2NC5P3C      18743368               176602          NaN
# 4139144650PO3NC3E3C      31591466                37086          NaN
# 4566944700PO3NC4A9C      31992642                25868          NaN
# 4302844664PO2NC5K5C      37117632                64892          NaN
# 4139144923PO1NC3H3C      48057090                18402          NaN
# 4123744641PO1NC4N2S      53342612               130092          NaN
#
#                       MT.Percentage
# SampleID
# 4146045001PO3NC4G4C             NaN
# 4129944963PO2NC4M1S             NaN
# 4520844650PO1NC5A7S             NaN
# 4146045001PO2NC3F4C             NaN
# 4520844650PO2NC3B7S             NaN
# 3905345005PO1NC2I1S             NaN
# 4129944963PO1NC3N1S             NaN
# 4211144957PO1NC3K4C             NaN
# 4660644938PO2NC3A10C            NaN
# 4139144923PO4NC4K3C             NaN
# 4598244908PO1NC3J8C             NaN
# 4598244908PO2NC4K8C             NaN
# 4566944964PO2NC4C7C             NaN
# 4129944963PO3NC3O1S             NaN
# 4139144923PO3NC5J3C             NaN
# 4566944964PO3NC3D8C             NaN
# 4265145042PO3NC4G5S             NaN
# 4598245001PO2NC4F8C             NaN
# 4499445005PO2NC3C5C             NaN
# 4660644993PO2NC5D10C            NaN
# 4566944964PO4NC3E8C             NaN
# 4660644938PO3NC5B10C            NaN
# 4636344664PO1NC5L9C             NaN
# 4566944700PO1NC5O8C             NaN
# 4636344914PO1NC4H9C             NaN
# 4265145042PO2NC4N4S             NaN
# 4660644993PO3NC5E10C            NaN
# 4211144957PO2NC3L4C             NaN
# 3889744700PO1NC5D1S             NaN
# 4265145042PO1NC3E5S             NaN
# 4660644993PO4NC5F10C            NaN
# 4146044643PO3NC5A4C             NaN
# 4146045001PO1NC5E4C             NaN
# 4139144650PO1NC4F3C             NaN
# 4139144650PO2NC4G3C             NaN
# 4520844650PO3NC5C8S             NaN
# 4566944700PO2NC5P8C             NaN
# 4146044643PO1NC5O3C             NaN
# 4456444991PO1NC3H6C             NaN
# 4139144923PO2NC3I3C             NaN
# 4146044643PO2NC5P3C             NaN
# 4139144650PO3NC3E3C             NaN
# 4566944700PO3NC4A9C             NaN
# 4302844664PO2NC5K5C             NaN
# 4139144923PO1NC3H3C             NaN
# 4123744641PO1NC4N2S             NaN

# %%
metadata.index
# Out:
# Index(['4146045001PO3NC4G4C', '4129944963PO2NC4M1S', '4520844650PO1NC5A7S',
#        '4146045001PO2NC3F4C', '4520844650PO2NC3B7S', '3905345005PO1NC2I1S',
#        '4129944963PO1NC3N1S', '4211144957PO1NC3K4C', '4660644938PO2NC3A10C',
#        '4139144923PO4NC4K3C', '4598244908PO1NC3J8C', '4598244908PO2NC4K8C',
#        '4566944964PO2NC4C7C', '4129944963PO3NC3O1S', '4139144923PO3NC5J3C',
#        '4566944964PO3NC3D8C', '4265145042PO3NC4G5S', '4598245001PO2NC4F8C',
#        '4499445005PO2NC3C5C', '4660644993PO2NC5D10C', '4566944964PO4NC3E8C',
#        '4660644938PO3NC5B10C', '4636344664PO1NC5L9C', '4566944700PO1NC5O8C',
#        '4636344914PO1NC4H9C', '4265145042PO2NC4N4S', '4660644993PO3NC5E10C',
#        '4211144957PO2NC3L4C', '3889744700PO1NC5D1S', '4265145042PO1NC3E5S',
#        '4660644993PO4NC5F10C', '4146044643PO3NC5A4C', '4146045001PO1NC5E4C',
#        '4139144650PO1NC4F3C', '4139144650PO2NC4G3C', '4520844650PO3NC5C8S',
#        '4566944700PO2NC5P8C', '4146044643PO1NC5O3C', '4456444991PO1NC3H6C',
#        '4139144923PO2NC3I3C', '4146044643PO2NC5P3C', '4139144650PO3NC3E3C',
#        '4566944700PO3NC4A9C', '4302844664PO2NC5K5C', '4139144923PO1NC3H3C',
#        '4123744641PO1NC4N2S'],
#       dtype='object', name='SampleID')

# %%
use_features = pd.read_csv(feature_path, header=None, index_col=0).index
use_features.name = var_dim
use_features
# Out:
# Index(['chr1_0', 'chr1_2', 'chr1_3', 'chr1_4', 'chr1_5', 'chr1_6', 'chr1_7',
#        'chr1_8', 'chr1_9', 'chr1_10',
#        ...
#        'chrX_1524', 'chrX_1525', 'chrX_1526', 'chrX_1527', 'chrX_1528',
#        'chrX_1529', 'chrX_1530', 'chrX_1531', 'chrX_1532',
#        'chrX_NW_021160383v1_random_0'],
#       dtype='object', name='chrom100k', length=23803)

# %%
#MCDS
total_mcds = MCDS.open(mcds_path,
                       var_dim=var_dim,
                       use_obs=metadata.index).sel({var_dim: use_features})
total_mcds
# Out:
# <xarray.MCDS>
# Dimensions:          (cell: 46, chrom100k: 23803, count_type: 2, mc_type: 3)
# Coordinates:
#   * cell             (cell) <U20 '4146045001PO3NC4G4C' ... '4123744641PO1NC4N2S'
#   * chrom100k        (chrom100k) <U29 'chr1_0' ... 'chrX_NW_021160383v1_rando...
#     chrom100k_chrom  (chrom100k) <U27 'chr1' ... 'chrX_NW_021160383v1_random'
#     chrom100k_end    (chrom100k) int64 100000 300000 400000 ... 153300000 68997
#     chrom100k_start  (chrom100k) int64 0 200000 300000 ... 153100000 153200000 0
#   * count_type       (count_type) <U3 'mc' 'cov'
#   * mc_type          (mc_type) <U3 'CHN' 'CAN' 'CGN'
# Data variables:
#     chrom100k_da     (cell, chrom100k, mc_type, count_type) uint32 dask.array<chunksize=(26, 6157, 1, 1), meta=np.ndarray>
# Attributes:
#     obs_dim:  cell
#     var_dim:  chrom100k

# %%
#add mC Rate 
total_mcds.add_mc_rate(var_dim=var_dim,
                       normalize_per_cell=True,
                       clip_norm_value=10)

total_mcds
# Out:
# <xarray.MCDS>
# Dimensions:            (cell: 46, chrom100k: 23803, count_type: 2, mc_type: 3)
# Coordinates:
#   * cell               (cell) <U20 '4146045001PO3NC4G4C' ... '4123744641PO1NC...
#   * chrom100k          (chrom100k) <U29 'chr1_0' ... 'chrX_NW_021160383v1_ran...
#     chrom100k_chrom    (chrom100k) <U27 'chr1' ... 'chrX_NW_021160383v1_random'
#     chrom100k_end      (chrom100k) int64 100000 300000 ... 153300000 68997
#     chrom100k_start    (chrom100k) int64 0 200000 300000 ... 153200000 0
#   * count_type         (count_type) <U3 'mc' 'cov'
#   * mc_type            (mc_type) <U3 'CHN' 'CAN' 'CGN'
# Data variables:
#     chrom100k_da       (cell, chrom100k, mc_type, count_type) uint32 dask.array<chunksize=(26, 6157, 1, 1), meta=np.ndarray>
#     chrom100k_da_frac  (cell, chrom100k, mc_type) float64 dask.array<chunksize=(26, 6157, 1), meta=np.ndarray>
# Attributes:
#     obs_dim:  cell
#     var_dim:  chrom100k

# %%
# we are not downsampleing, therefore: 
mcds = total_mcds
mcds
# Out:
# <xarray.MCDS>
# Dimensions:            (cell: 46, chrom100k: 23803, count_type: 2, mc_type: 3)
# Coordinates:
#   * cell               (cell) <U20 '4146045001PO3NC4G4C' ... '4123744641PO1NC...
#   * chrom100k          (chrom100k) <U29 'chr1_0' ... 'chrX_NW_021160383v1_ran...
#     chrom100k_chrom    (chrom100k) <U27 'chr1' ... 'chrX_NW_021160383v1_random'
#     chrom100k_end      (chrom100k) int64 100000 300000 ... 153300000 68997
#     chrom100k_start    (chrom100k) int64 0 200000 300000 ... 153200000 0
#   * count_type         (count_type) <U3 'mc' 'cov'
#   * mc_type            (mc_type) <U3 'CHN' 'CAN' 'CGN'
# Data variables:
#     chrom100k_da       (cell, chrom100k, mc_type, count_type) uint32 dask.array<chunksize=(26, 6157, 1, 1), meta=np.ndarray>
#     chrom100k_da_frac  (cell, chrom100k, mc_type) float64 dask.array<chunksize=(26, 6157, 1), meta=np.ndarray>
# Attributes:
#     obs_dim:  cell
#     var_dim:  chrom100k

# %%
# Highly variable features
#mCH

if hvf_method == 'SVR':
    # use SVR based method
    mch_hvf = mcds.calculate_hvf_svr(var_dim=var_dim,
                                     mc_type=mch_pattern,
                                     n_top_feature=n_top_feature,
                                     plot=True)
else:
    # use bin based method
    mch_hvf = mcds.calculate_hvf(var_dim=var_dim,
                                 mc_type=mch_pattern,
                                 min_mean=0,
                                 max_mean=5,
                                 n_top_feature=n_top_feature,
                                 bin_min_features=5,
                                 mean_binsize=0.05,
                                 cov_binsize=100)
# Out:
# /home/ehabibi/.conda/envs/allcools/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/ehabibi/.conda/envs/allcools/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# n_top_feature is than total number of features, will use all features
# Fitting SVR with gamma 0.0420, predicting feature dispersion using mc_frac_mean and cov_mean.
# Total Feature Number:     23803
# Highly Variable Feature:  23803 (100.0%)
# /home/ehabibi/.conda/envs/allcools/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/ehabibi/.conda/envs/allcools/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/ehabibi/.conda/envs/allcools/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/ehabibi/.conda/envs/allcools/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))

# %%
#save AnnData

total_mcds.coords[f'{var_dim}_{mch_pattern}_feature_select'] = mcds.coords[
    f'{var_dim}_{mch_pattern}_feature_select']

# %%
mch_adata = total_mcds.get_adata(mc_type=mch_pattern,
                           var_dim=var_dim,
                           select_hvf=True)

# %%
mch_adata.write_h5ad(f'mCH.HVF.h5ad')

mch_adata
# Out:
# AnnData object with n_obs × n_vars = 46 × 23803
#     var: 'chrom', 'end', 'start', 'CHN_mean', 'CHN_dispersion', 'CHN_cov', 'CHN_score', 'CHN_feature_select'

# %%
# mCG
if hvf_method == 'SVR':
    # use SVR based method
    mcg_hvf = mcds.calculate_hvf_svr(var_dim=var_dim,
                                     mc_type=mcg_pattern,
                                     n_top_feature=n_top_feature,
                                     plot=True)
else:
    # use bin based method
    mcg_hvf = mcds.calculate_hvf(var_dim=var_dim,
                                 mc_type=mcg_pattern,
                                 min_mean=0,
                                 max_mean=5,
                                 n_top_feature=n_top_feature,
                                 bin_min_features=5,
                                 mean_binsize=0.02,
                                 cov_binsize=20)
# Out:
# n_top_feature is than total number of features, will use all features
# Fitting SVR with gamma 0.0420, predicting feature dispersion using mc_frac_mean and cov_mean.
# Total Feature Number:     23803
# Highly Variable Feature:  23803 (100.0%)

# %%
# save AnnData
total_mcds.coords[f'{var_dim}_{mcg_pattern}_feature_select'] = mcds.coords[
    f'{var_dim}_{mcg_pattern}_feature_select']

# %%
mcg_adata = total_mcds.get_adata(mc_type=mcg_pattern,
                                 var_dim=var_dim,
                                 select_hvf=True)

mcg_adata.write_h5ad(f'mCG.HVF.h5ad')

mcg_adata
# Out:
# AnnData object with n_obs × n_vars = 46 × 23803
#     var: 'chrom', 'end', 'start', 'CHN_mean', 'CHN_dispersion', 'CHN_cov', 'CHN_score', 'CHN_feature_select', 'CGN_mean', 'CGN_dispersion', 'CGN_cov', 'CGN_score', 'CGN_feature_select'
